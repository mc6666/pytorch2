# %%
# !pip install torch torchvision torchaudio -U
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.9/619.9 MB 2.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 111.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 107.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.1/177.1 MB 7.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.6/102.6 MB 10.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 MB 13.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 4.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.2/173.2 MB 7.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 KB 64.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 KB 15.9 MB/s eta 0:00:00
# ...

# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.5/485.5 KB 18.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.1/189.1 KB 17.1 MB/s eta 0:00:00
# ...

# %%
# !pip show torch
# Out:
# Name: torch
# Version: 2.0.0
# Summary: Tensors and Dynamic neural networks in Python with strong GPU acceleration
# Home-page: https://pytorch.org/
# Author: PyTorch Team
# Author-email: packages@pytorch.org
# License: BSD-3
# Location: /usr/local/lib/python3.9/dist-packages
# Requires: filelock, jinja2, networkx, nvidia-cublas-cu11, nvidia-cuda-cupti-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cuda-runtime-cu11, nvidia-cudnn-cu11, nvidia-cufft-cu11, nvidia-curand-cu11, nvidia-cusolver-cu11, nvidia-cusparse-cu11, nvidia-nccl-cu11, nvidia-nvtx-cu11, sympy, triton, typing-extensions
# Required-by: fastai, thop, torchaudio, torchtext, torchvision, triton, ultralytics

# %%
# !yolo predict model=yolov8n.pt source="https://ultralytics.com/images/bus.jpg"
# Out:
# 2023-03-21 13:30:44.641509: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-21 13:30:45.846932: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib/python3.9/dist-packages/cv2/../../lib64:/usr/lib64-nvidia
# ...

# %%
# !gdown https://drive.google.com/uc?id=1eIk-6xgv3p_6r5eOiAPelZtZYeWYzSgq
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1eIk-6xgv3p_6r5eOiAPelZtZYeWYzSgq
# To: /content/Dollar_Bill.zip
# 100% 154M/154M [00:02<00:00, 66.6MB/s]

# %%
ls ./Dollar_Bill.zip -l
# Out:
# -rw-r--r-- 1 root root 153715876 Mar 21 13:30 ./Dollar_Bill.zip

# %%
# !unzip ./Dollar_Bill.zip
# Out:
# 串流輸出內容已截斷至最後 5000 行。
#   inflating: datasets/train/images/IMG_1898_jpg.rf.ac1e828572574cce67e8aa0ae14cec6f.jpg
#   inflating: datasets/train/images/IMG_1898_jpg.rf.b37c1b6b4d55c457ecc21af7e6df7adb.jpg
#   inflating: datasets/train/images/IMG_1898_jpg.rf.b61233066645bc8cfc2f116b7589e1c5.jpg
#   inflating: datasets/train/images/IMG_1898_jpg.rf.c566f2e73a73e35b83452ecf8af2dc33.jpg
#   inflating: datasets/train/images/IMG_1898_jpg.rf.c7bd46874315e3311ea4593964800817.jpg
#   inflating: datasets/train/images/IMG_1898_jpg.rf.d7df8c0d7e0b2925074629f4ceec6129.jpg
#   inflating: datasets/train/images/IMG_1899_jpg.rf.0fe5a41e44b4403a37ab7d3a49630e5f.jpg
#   inflating: datasets/train/images/IMG_1899_jpg.rf.1186450c6f112b902fddb78f384bfa58.jpg
#   inflating: datasets/train/images/IMG_1899_jpg.rf.31b2f475cd38504ec25c8e4a1a8717cf.jpg
#   inflating: datasets/train/images/IMG_1899_jpg.rf.6c256a9b7132085eba6e0889a02f35c3.jpg
# ...

# %%
# !which python
# Out:
# /usr/local/bin/python

# %%
# %cd /usr/local/lib/python3.9/dist-packages/ultralytics/yolo/engine
# Out:
# /usr/local/lib/python3.9/dist-packages/ultralytics/yolo/engine

# %%
ls
# Out:
# exporter.py  model.py      __pycache__/  trainer.py
# __init__.py  predictor.py  results.py    validator.py

# %%
# !rm trainer.py

# %%
from google.colab import files
files.upload(); #'./trainer.py'
# Out:
#      <input type="file" id="files-22375315-d4be-4dec-b435-cdfd741ac82f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-22375315-d4be-4dec-b435-cdfd741ac82f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
files.download('./trainer.py')

# %%
cd /content
# Out:
# /content

# %%
from datetime import datetime
datetime.now()
# Out:
# datetime.datetime(2023, 3, 21, 0, 43, 47, 410318)

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=./data.yaml epochs=5 imgsz=640
# Out:
# Ultralytics YOLOv8.0.55 🚀 Python-3.9.16 torch-2.0.0+cu117 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from datetime import datetime
datetime.now()
# Out:
# datetime.datetime(2023, 3, 21, 0, 51, 5, 328982)

# %%
# !yolo task=detect mode=val model=./runs/detect/train2/weights/best.pt data=./data.yaml
# Out:
# 2023-03-21 00:52:35.655402: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-21 00:52:36.789454: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib/python3.9/dist-packages/cv2/../../lib64:/usr/local/lib/python3.9/dist-packages/cv2/../../lib64:/usr/lib64-nvidia
# ...

# %%
from ultralytics import YOLO
from PIL import Image
import cv2

model = YOLO("./runs/detect/train2/weights/best.pt")

# from PIL
im1 = Image.open("./datasets/test/images/IMG_1909_jpg.rf.3f2bde8dc899b141a4361677e55242e4.jpg")
# save=True：存檔
results = model.predict(source=im1, save=True)
# Out:
# 0: 640x640 1 twenty-back, 17.5ms
# Speed: 0.7ms preprocess, 17.5ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict

# %%
ls runs/detect/predict
# Out:
# image0.jpg

# %%
from IPython.display import Image
Image('./runs/detect/predict/image0.jpg')
